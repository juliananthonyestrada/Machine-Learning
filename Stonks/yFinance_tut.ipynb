# %%
import yfinance
import numpy as np

import matplotlib.pyplot as plt


snp_ticker = "VOO"
snp = yfinance.Ticker(snp_ticker)

# Fetch historical data for the last year
data = snp.history(period="1y")
plt.scatter(np.linspace(0, len(data), len(data)), data["Open"])
plt.show()

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import requests

url = "https://stockanalysis.com/list/biggest-companies/"
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers)
tables = pd.read_html(response.text)
symbols = tables[0]["Symbol"].tolist()
print(symbols)
print(len(symbols))
market_caps = {}
for ticker in symbols:
    try:
        info = yf.Ticker(ticker).info
        market_cap = info.get("marketCap", None)
        if market_cap:
            market_caps[ticker] = market_cap
    except Exception as e:
        print(f"Error fetching data for {ticker}: {e}")
        continue 
print("Finished fetching market caps.")

# top_500 as this is all i can scrape with this method
top_500 = dict(sorted(market_caps.items(), key=lambda x: x[1], reverse=True))
plt.figure(figsize=(10, 10))
plt.pie(top_500.values(), labels=top_500.keys(), autopct="%1.1f%%")
plt.title("Market Cap Distribution of Russell 1000 Companies")
plt.show()
# Out:
# C:\Users\ARamo\AppData\Local\Temp\ipykernel_18864\1263529585.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
# ...

# %%
import pandas as pd
import requests

url = "https://stockanalysis.com/list/biggest-companies/"
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers)
tables = pd.read_html(response.text)

for i, table in enumerate(tables):
    print(f"Table {i} columns: {table.columns.tolist()}")
    print(table)
    print("\n---\n")
# Out:
# Table 0 columns: ['No.', 'Symbol', 'Company Name', 'Market Cap', 'Stock Price', '% Change', 'Revenue']
#      No. Symbol                 Company Name Market Cap  Stock Price % Change  \
# 0      1   NVDA           NVIDIA Corporation  4,105.73B      168.960    0.39%
# 1      2   MSFT        Microsoft Corporation  3,709.26B      499.020    0.16%
# 2      3   AAPL                   Apple Inc.  3,464.04B      233.420   -1.87%
# 3      4  GOOGL                Alphabet Inc.  2,898.69B      239.680    2.41%
# 4      5   AMZN             Amazon.com, Inc.  2,541.56B      238.310    1.05%
# ..   ...    ...                          ...        ...          ...      ...
# 495  496    FIX    Comfort Systems USA, Inc.     24.96B      708.920   -0.97%
# 496  497     IP  International Paper Company     24.80B       46.980   -0.91%
# 497  498    NOK                    Nokia Oyj     24.76B        4.585   -0.11%
# 498  499   PODD          Insulet Corporation     24.73B      351.300    0.50%
# ...
